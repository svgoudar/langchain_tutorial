# %% [markdown]
# ## LangChain Expression Language (LCEL)
#
# This section covers **LCEL patterns and the Runnable interface** for composing modular, production-ready LangChain applications.
#
# LCEL provides **declarative chain composition, streaming, async execution, and retry logic** through a powerful and elegant syntax.

# %% [markdown]
# ```{dropdown} Click here for Sections
# ```{tableofcontents}
# ```
