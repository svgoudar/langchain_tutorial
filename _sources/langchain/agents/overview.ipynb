# %% [markdown]
# ## LangChain Agents
#
# This section covers **agent patterns and implementations** in LangChain for building autonomous AI systems that can reason, plan, and take actions.
#
# Agents transform LLMs from passive text generators into **active decision-making systems** that can use tools, maintain memory, and execute multi-step workflows.

# %% [markdown]
# ```{dropdown} Click here for Sections
# ```{tableofcontents}
# ```
